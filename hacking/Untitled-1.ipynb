# %% [markdown]
# Simple idea:
#
#     - We can partition our code / functionality into two streams:
#     i) Finding whales / profitable wallets etc.
#     ii) Mapping these wallets to something.
#
# Example of i) we already have written some `early_whales` functionality. For ii) we could use `intersect_dict` functionality. e.g. after identifying several wallets of interest (through whatever means) once per day we could run some code to compute the current intersection of their portfolios. How this might play out: we identify 20 wallets that are highly profitable. Some were early pepe whales, for example. Then, once per day, we run some code to compute the intersection of their portfolios. We notice that 8/20 have purchased a coin $\theta$. Maybe $\theta$ is a newly launched coin - this would be of particular interest! Maybe $\theta$ is a "trending" token. And so on.
#
# Anyway, we basically have the functionality to do this (once given the wallets of interest - which we already have a few of).

# %%
from api_endpoints.etherscan_api import *
from api_endpoints.covalent_api import *
from etherscan import Etherscan #externally installed package https://github.com/pcko1/etherscan-python

# %% [markdown]
# This code seems to do what we want. Just need to wrap it into a nice class / function.

# %%
###Setup
chainName='eth-mainnet'
cov_api = Covalent_Api() #might need to pass an API key (different to default -- see __init__ of class)
###

#Inputs:
wallet_1 = '0xaf2358e98683265cbd3a48509123d390ddf54534' #this guy is an early pepe whale
wallet_2 = '0x711281c1b26aaed86e40e4caaf76c1962b45e161' #this guy is an early pepe whale
n_lst = [{'address':wallet_1},{'address':wallet_2}]
#wallet_1 >> wallet_2, but yeah.

#Out
#now update token holders info by getting their whole portfolios on the given `date`. We take the list output from `get_token_holders` and update it with the portfolio info.
date = '2023-09-24' #todays date. Want this to automatically gets todays date!
portfolios = cov_api.get_holders_portfolios(n_lst=n_lst,chainName=chainName,date=date)

union_portfolios  = union_top_n(portfolios)#i.e. all the tokens ("union")
intersect_dict = intersection_count(portfolios,union_portfolios)

# %%
contract_name_if_k_holders(intersect_dict,2)
# Out:
# [('Inflation', '0x7abb69ad9d1e4dffac04c0f71f0bd38db51da13b'),
#  ('SPGBB', '0x64551fa4093c2d6c298cf1792740f884084a8f69'),
#  ('ShibariumLock', '0x7a8476d428ef3d98189ba393e4020779b8fd9097'),
#  ('Bitcoin', '0xe03b2642a5111ad0efc0cbce766498c2dd562ae9'),
#  ('Pepe Uchiha', '0x854297f187da349e40fea858f99e7a61b389aa17'),
#  ('0xCBot', '0x04d9bf3e6ded84189b722964bf0b3328a0c9ba01'),
#  ('RUGame Labs', '0x34721a7a561619e062c0ff860741037c7462a056'),
#  ('Wrapped BTC', '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'),
#  ('Angry Panda', '0xfb3e4f85735bd3a733579d877aa8d1dbf2eacbb2'),
#  ('Prime', '0xb23d80f5fefcddaa212212f028021b41ded428cf'),
#  ('Courage', '0xbe5f9d8cfbb5b13cc8944837dd92845fd39b5b1c'),
#  ('Gridcraft', '0xcbc6922bb75e55d7ca5dabcf0ea2d7787fd023f6'),
#  ('StarLink', '0x8e6cd950ad6ba651f6dd608dc70e5886b1aa6b24'),
#  ('MEOW', '0xad7468fe14eba021b3cdd8f929d69bb519c66e47'),
#  ('Pomeranian', '0x24ffe459f51ea20c5d8ad49843529fc33654e7e4'),
#  ('Temple of Retards', '0xd35495f157a5101ba6e877aa89ea79bb734c8d2a'),
#  ('AficionaDAO', '0x4ce9975a510d9b02ecca7541bc94c5530c1b1929'),
#  ('Ethereum Capital Finance', '0x0cb76ba39b5b860a28b91343d715fce2a2ecb3b4'),
#  ('Unimoon', '0x71de2285ec83bb6517d2b3ec8deb2a6c44d8c5da'),
#  ('BLUE', '0x96b00208911d72ea9f10c3303ff319427a7884c9'),
#  ('Wrapped Ether', '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'),
#  ('Pepe Guardiola', '0xfdf9e6c20166d5f055483c63b3e62b00f8dbd6ca'),
#  ('USDC Classic', '0x4133bd69be307b01f72d6d9f331e18bc661f6f30'),
#  ('Bitcoin Pizza', '0x41fb942e3b39c8812705a74049378abfa41f40c7'),
#  ('Grippy', '0x6b08cd9d07eb604e3e30615521eb286a0cebde4c'),
#  ('Tkuma ', '0x6d7110ce7f2e67b0f158bde38ef8a408df16490f'),
#  ('Dogens', '0x1b4dd5ea240732ddac8d74fd1cd9026addc02e3c'),
#  ('Woolong', '0xe99191fb0eddd33d0cf57a5b28ddf31861b9c0c1'),
#  ('Loyal', '0xde6320c6513b2b50adab60060af05c98d02f3070'),
#  ('Non Human Intelligence', '0x1bef0d587dde09d4cee9b13d4d38b5bec57a1397'),
#  ('Mineable', '0x42b91f1d05afea671a2da3c780eda2abf0a2a366'),
#  ('Hammer Finance', '0x865dcdb3328a2b1fe28536493dd74e5704a344e5'),
#  ('Protectorate', '0xb9098d3669a78e9afe8b94a97290407400d9da31'),
#  ('BigBangLottery', '0x4b63f62f48d8026f0269218d640d403327cd09d8'),
#  ('KEKO', '0x2c7f442aab99d5e18cfae2291c507c0b5f3c1eb5'),
#  ('Pond0x', '0x1d4214081985ad20aa3ca93a2206ae792635cbec'),
#  ('The Path Of Light', '0x1ab052db3216835182926a6d516762b0f1634661'),
#  ('Slamdunk', '0xf17722b3efd7da25eaf45d109d35f4c6a479303f'),
#  ('PepeOfWallStreet', '0x8367039536cc1caa39901a82070726e1d0b1a7a9'),
#  ('HIKARI', '0xd4126f195a8de772eeffa61a4ab6dd43462f4e39'),
#  ('f0x', '0x3fa5c0af7043cc7e69afbaf91ff7c411820f4616'),
#  ('Mida', '0x57d8dc5ef3762395ab1e842473354cec9ab14f5b'),
#  ('AirDrop Protocol', '0x4a62a4165d810cedf41e8b19a011e763b03e960e'),
#  ('RociFi', '0xf51092fe93b4e9282f42c459f05d93d2d079549e'),
#  ('HarryPotterObamaGaryMarioinu23',
#   '0x21007ec8dfb0c5723891356043d2aea6650d56e3'),
#  ('VoxNET', '0x048aa6e69d5117bd665af4128383a6982b8367b3'),
#  ('Ether', '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee'),
#  ('Eggs', '0x2e516ba5bf3b7ee47fb99b09eadb60bde80a82e0'),
#  ('THAT', '0x27c83a46b37303a5168e739e8dd9629750c3724b'),
#  ('Autistic Degen Network', '0x914ad6483b59eae99cfbee263c601206764d715f'),
#  ('The Triune Pact', '0xee24f8b6638ad711105434fee7a2bed911846d2f'),
#  ('FROOTZ', '0xcc796095cc939e97b59bb34fb2ba0e1515b12cea'),
#  ('Woof Money', '0x3ffadab7e92e101f9ae6d0ae06db6aef16da1c58'),
#  ('Elmo', '0x335f4e66b9b61cee5ceade4e727fcec20156b2f0'),
#  ('Shytoshi Coin', '0x97e656646e174ea47d95c8e8ba8361a80d74e8fc'),
#  ('Steve', '0x54debe126da16a8fcaa67285d6830c3a7c6752fd'),
#  ('ペペ2.0', '0xbe65d053dea8998c3c63dedd088e6bf464aea51b'),
#  ('BenisAintFree23Cents', '0x03e78f2665e474a42eeed875f6198590da10948b'),
#  ('Sheeba Inu', '0xa83055eaa689e477e7b2173ed7e3b55654b3a1f0'),
#  ('Nobi', '0xc5253c32bb72921b77ae18cf329dad5e6c3de5a4'),
#  ('Half Pepe', '0x0a1024637064dfe24bb1fa6b0ef6cb2a77f4771b'),
#  ('Not Financial Advice', '0x8eecaad83a1ea77bd88a818d4628fafc4cad7969'),
#  ('SavePepe', '0x15d0250d039f6f430cd387e07beb97ff81a8225e'),
#  ('LMEOW', '0x5f99c811b4c26f0afb4072ee6cc99d3a03b75ee7'),
#  ('dog.catcher', '0x679a0b65a14b06b44a0cc879d92b8bb46a818633'),
#  ('FATE', '0x332a6d4dcafbb74ac7cc8a42c0edf0542f2fb668'),
#  ('Pepe', '0x6982508145454ce325ddbe47a25d4ec3d2311933'),
#  ('Froge', '0xe9a97b0798b1649045c1d7114f8c432846828404'),
#  ('Ordinal DEX', '0x4190943ce03adf61ca88b4fab66b6dc99437f3d7'),
#  ('IMX', '0x88129146ec0a3332eba05f721d963868d8284254'),
#  ('Peperoni', '0xd70cf7bb0d4e3a4dda7d818080424a4e683f72fa'),
#  ('Tether USD', '0xdac17f958d2ee523a2206206994597c13d831ec7'),
#  ('Gas DAO', '0x6bba316c48b49bd1eac44573c5c871ff02958469'),
#  ('Magic Internet Money', '0x99d8a9c45b2eca8864373a26d1459e3dff1e17f3'),
#  ('BLACK SHEEP UNITED', '0x1ae3dabb2924940ff4115df190875e475c429254'),
#  ('Quant', '0x4a220e6096b25eadb88358cb44068a3248254675'),
#  ('May The 4th Be With You', '0x7148a7af3e6b42ec46462edbb38d870ec6b52dcb'),
#  ('Engagement Virtual Assistant',
#   '0x059240d8ded9df6d67551a09b98a5ad92a5fa127'),
#  ('Stonks', '0x47c215e35e1a884c808b21f78bc2abfcf4dbf028'),
#  ('Proof of Existence', '0x7602b51791203f30cc23279d3ff7eff899ef8a09'),
#  ('PRIMATE', '0x46e98ffe40e408ba6412beb670507e083c8b95ff'),
#  ('AssangeDAO', '0x59d1e836f7b7210a978b25a855085cc46fd090b5'),
#  ('Dogechain Token', '0x7b4328c127b85369d9f82ca0503b000d09cf9180'),
#  ('KokanKano', '0x07c4f57790a9b9372adb2516bd41c99fc38c7170'),
#  ('UpOnly', '0xa718b5c51f4d3ee6eaaa286b2e4192d5e8106a29'),
#  ('F9 DAO', '0xdd0ef0b2de3efec847a79b4ce4de52c4bb98f488'),
#  ('Wrapped UST Token', '0xa47c8bf37f92abed4a126bda807a7b7498661acd'),
#  ('TWOPAW Token', '0xf7de6def3d319811418d69bf56c532a815fc47e8'),
#  ('SALT', '0xb010f0a8ee6afa6e04377d209277a9527a963dd5'),
#  ('Tokemak', '0x2e9d63788249371f1dfc918a52f8d799f4a38c94'),
#  ('The Guest List', '0xcc4450edefbbeb450e2f205f4eceff7232d54e92'),
#  ('RISITAS', '0x71ef960cfc4d868e42a1fd4ad24d70e6a2002ff1'),
#  ('Shibereum.Ai', '0xe90b7c42df81f8ef847769a78cbdb5ffc3fca9cc'),
#  ('Pepe Inu', '0x99cfb8cba9c821b4a343c6a1fc630465c9708df5'),
#  ('YouTube Coin', '0xd83802b55964909126aa96944dd7ef298c7605cd'),
#  ('PepeTard', '0x38a9a06bde45745b6bed2a3bf516ef20fc10f70f'),
#  ('Ushi', '0x6dca182ac5e3f99985bc4ee0f726d6472ab1ec55'),
#  ('AIBO INU', '0x03cc9bbf67a3650723a20cb71a9d84468570e962'),
#  ('BONER', '0x82ef12d87bf31185fb0110e9f55e1e63dbfa7551'),
#  ('Black Eyed Dragon', '0x59b44e9ac4ab8e29db6faf7bacd726c6b7bc94b9'),
#  ('reee.finance', '0xc723852cbd3002999510cc65a673c3a986c4f1f9'),
#  ('GameStop Degen Corp', '0x433117819df60cb943ec57fbc885c894c5602e1e'),
#  ('FUD Coin', '0xfa6719140639dc225840d4d5df9ef92a3d3c7d20'),
#  ('Nick Szabo', '0x8b3bbecdf48002ab2a0fd2894459d8d0737578b2'),
#  ('XWIZARD', '0x7fc09a4f6182e835a97c42980f7235e8c0cbfa56'),
#  ('MemeCrafter', '0xcf86f09accd244e3c81ec2bc335c53939ee0248e'),
#  ('ClippyAI', '0xe63aaf6e15c3be082e5dcabf535984fdbf7e2e1f'),
#  ('Shintama 2.0', '0x9160fc91757bf269b17e635ed8c726378b197e21'),
#  ('Do Good', '0xe32ca1c29c3c918a5982ac01e03c42c63ac4aecc'),
#  ('Ethereum Message Service', '0x247dc9cbbaadabce6e30e2a84ec6c53a419913ad'),
#  ('SquadTrade', '0xf0342613dfe450b2a5372eedf96358e4a00dd36f'),
#  ('UpRising', '0x86ad1f47874fc7542524ae04518205682abbc276'),
#  ('Schipperke Inu', '0x98ada56008fb2998e14c9f37818e663f689e2252'),
#  ('Church DAO', '0x71018cc3d0ccdc7e10c48550554ce4d4e3afd9c1'),
#  ('Duck Coin', '0xfd683737b72cc710757a76c9a1c373a3a3a9afb0'),
#  ('ApeCoin', '0x4d224452801aced8b2f0aebe155379bb5d594381'),
#  ('Baby Shiba Inu', '0x00000000051b48047be6dc0ada6de5c3de86a588'),
#  ('CONGRATULATIONS - YOU MADE IT! Welcome to CULTURE PASS Token! CULTURE PASS token is a gateway to riches. Holding CULTURE PASS allows the holder to be the first to buy ?????? -- the secretive meme coin that has been in the works for months.',
#   '0x41f0752d00b1aee6132e6b90142d7f87cede6422'),
#  ('Rebase Panda', '0x9256c9b0bb0cda4b7fbf8212f80184eb1da17e7a'),
#  ('USD Coin', '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'),
#  ('Crypto EGG', '0xe99c0f63c5f4171e98d41abd80df872c883e8ad5'),
#  ('Something', '0x5e0063352e5d4becb1ae9877580b9c9a3e5302c9'),
#  ('The Dog Standard', '0x80fdc79c446763a2879a23c634845f9578966989'),
#  ('Boobs', '0x8ca82016e5efc3b028c4bd7ed35c3d6585105360'),
#  ('MATH', '0xe89751b31cd4e2eb7006ce168857f72c8e37bceb'),
#  ('WOOGIE', '0x4aa2d678ec948bf573e531dcd02c0d53009a5cc2'),
#  ('Reward Tracker', '0x6327944b4f798a3797bbb802f2c02d308748187e'),
#  ('Billy Token', '0x9cbf044bc535db4c93a9f11205a69631d9dcef26'),
#  ('Dolan', '0xd4690fe42336a39ba0d7b94eb8f4e52e11e74ec4'),
#  ('WoofWork.io', '0x6bc08509b36a98e829dffad49fde5e412645d0a3'),
#  ('Giant Sequoia', '0x1a7bdaf43e643ec677458f09d5b6d2bdedd681a7'),
#  ('Chicks', '0x1170c095fd603f0022761db8da0b5f3dfa77cf03'),
#  ('RarePepe', '0x9072b3c9bf36b6583b6f0bcf35193121ff3ecf82'),
#  ('Skyward', '0x83e06d480d38c7c0cc60b2ae775c2bf9c23e459d'),
#  ('FAKE Token', '0x93c35835e4ed124b335491351ad1cf7688932dfb'),
#  ('Pepe Flix', '0xdb0db064e287ca6d57f74d97dc9e32ff4e5eced8'),
#  ('环球股', '0x57b9d10157f66d8c00a815b5e289a152dedbe7ed'),
#  ('Hedgedoge', '0x9aec0bd79fd2ee8949c7360923c24b6266f643a8'),
#  ('SurrealCreations', '0xe518e935954406a214c62e246d8cee8b0d7231f4'),
#  ('Bomberman', '0x492e48df25612c9c1987580d0038861e7162edbd'),
#  ('revoAI', '0x8793fb615eb92822f482f88b3137b00aad4c00d2'),
#  ('OkayCoins', '0x49bb71ca8bd422581dc36d1a96c4c11dd293148c'),
#  ('WOOFMEISTER', '0x5d13ace25d4171fcf24c7e230320bfc6809b00f8'),
#  ('BOB', '0x7d8146cf21e8d7cbe46054e01588207b51198729'),
#  ('Ethereum-Peg Proof Of Memes', '0x3bfcb1e14f2b1bfec9d611cd6b02d48ceef43491'),
#  ('OxAI', '0x428dca9537116148616a5a3e44035af17238fe9d'),
#  ('Flute', '0x4f08705fb8f33affc231ed66e626b40e84a71870'),
#  ('Trinity', '0x4813a4653a13b6cd69a6406da2e10a4ae85a06cc'),
#  ('They Dunno Yet', '0x34ac52a74631f4267a67ab6486ef52880f68b4c5'),
#  ('What', '0x8df566cb30994babc1bf4702b811a7afae47e043'),
#  ('ARCH', '0x73c69d24ad28e2d43d03cbf35f79fe26ebde1011'),
#  ('SpongePepeSquarePants', '0xb8a833e2332a70835df3bcaa3b35c79493b686e7'),
#  ('FLOKI', '0xcf0c122c6b73ff809c693db761e7baebe62b6a2e'),
#  ('BoneShiba', '0x71be2bb1a994447420915c4534cbf5d0305480a6'),
#  ('Falcon Heavy', '0x49c648ff81375b54673995978541cf2337679b70'),
#  ('Bet2Bank', '0xb69d946d8cdc5238b0658188e1babb41b8652a29'),
#  ('PLACE ON BLOCKCHAIN', '0x312d224a5549e1db291d386392592778781be0b4'),
#  ('The Chemist', '0xb2efc103f94deda445c48a06b9a720e60829b77a'),
#  ('Tren Inu', '0x317f36f56c9f3aae142db8df8fc1dafbe2b28e0b'),
#  ('WallStreetPepe', '0x02d3d5882490991970c35c9c6e3a64e03ffd4dfc'),
#  ('Paranoia', '0x1d67090d3854c6b9c6272888b559c2b59df102a5'),
#  ('Wendys', '0x041207bfc61b087c3e271f06c5501027367cf2eb'),
#  ('DumpsterDao', '0x60d469448b994cb55c0644e1fc91e86243741d40'),
#  ('Chronoly', '0xe23311294467654e0cab14cd32a169a41be5ca8e'),
#  ('VIRAL_Dividen_Tracker', '0xaa95d98a85aa74602a74707f3d167ad059f2fa9a'),
#  ('Ant Pepe', '0xa597788db0edeb21de7d0a54436b71cebeb57263'),
#  ('Pepe 2.0', '0xfb66321d7c674995dfcc2cb67a30bc978dc862ad'),
#  ('Beetlejuice', '0xbee00daf5b9c83d00a2fb684c7668f3088650035'),
#  ('Mumu the Bull', '0x50adfd48a5a7bb7cabb1743642427e7142b85427'),
#  ('Falcon 9', '0x38a94e92a19e970c144ded0b2dd47278ca11cc1f'),
#  ('KOYO', '0x198065e69a86cb8a9154b333aad8efe7a3c256f8'),
#  ('Yuna (YunaToken.io)', '0x2f6f397332b0f8b4536430bcc97980aa838f62f9'),
#  ('Teh Final Chapter', '0x05eba78ee7c1cbd994ff56dc87a00d8c1ab14e5d'),
#  ('Concave', '0x000000007a58f5f58e697e51ab0357bc9e260a04'),
#  ('Mev Maximus', '0x6289396d0678fdf92f431e9d042b2f0b94bd993d'),
#  ('Doge0.5', '0x337809309a61521a6eb0539702a1b027053948b5'),
#  ('ShibOriginalVision', '0x2c5bc2ba3614fd27fcc7022ea71d9172e2632c16'),
#  ('CloverBank', '0x0d74e8be1c7e3a0733d55ce12150faddab9d2f58'),
#  ('Pepereum Pro', '0x2cad596a6c4005e209cb7ef67f755df27227b1d2'),
#  ('BOB Classic', '0xc9fb76ae43e09554f1767e457b2682c6349668a2'),
#  ('Ai Smart Chain', '0xb7df0f42fae30acf30c9a5ba147d6b792b5eb9d9'),
#  ('X2Y2Token', '0x1e4ede388cbc9f4b5c79681b7f94d36a11abebc9'),
#  ('Checks Token', '0x049e9f5369358786a1ce6483d668d062cfe547ec'),
#  ('0.5', '0x3f381dd52fc2ec1d995f3603bb51ac0d9d443f4a'),
#  ('Rewardz Automated Yield Network',
#   '0x562d8e607bed7fc183ca84c0362c853680b99638'),
#  ('Hermes', '0xb012be90957d70d9a070918027655f998c123a88'),
#  ('HOOT', '0x12a7530d6f9e1a9b0351d78ab711f7c2c033873a'),
#  ('Karasu', '0x676495371d5107f870e0e7d5afb6fed91f236f21'),
#  ('JAKE', '0xebae9e33783d2ee9e92c01346d38f62cd8e17eda'),
#  ('Bitcoin20', '0xe86df1970055e9caee93dae9b7d5fd71595d0e18'),
#  ('Tesla.com', '0x0c0bbe9ebe707cef0da28999a9e72a059577267a'),
#  ('Waifu', '0x069516f60816bc1ddb362048c015dd814353f74b'),
#  ('Whistler', '0x4f39687328a14dba531fcbd2305724740bb36941'),
#  ('Boop', '0x8013266cb5c9dd48be3ad7d1ce832874d64b3ce1'),
#  ('HarryPotterObamaSonic10Inu', '0x72e4f9f808c49a2a61de9c5896298920dc4eeea9'),
#  ('KMask', '0xc3cab0d0918c39e29088c495a077ecd022758798'),
#  ('Modulus Domain Service', '0xa43a8fc632d809fb2c16f590c0ff6423e311c67d'),
#  ('ErcProtocol', '0x13817e7433e51273ff6e7b427e445b0edc014828'),
#  ('HODL4LYFE', '0x4e178b3a35ac5eb19f4900c00d9d21f4dd7df9e8'),
#  ('Yield AI', '0x43ac05a75cc0b37d1ec51e0a05fa7983ef53f03e'),
#  ('Milady', '0x12970e6868f88f6557b76120662c1b3e50a646bf'),
#  ('BREPE', '0xa0117792d4b100fd329b37e8ab4181df8a5b3326'),
#  ('DAOSquare Governance Token', '0xbd9908b0cdd50386f92efcc8e1d71766c2782df0'),
#  ('TadPole Man', '0x9fb6c9770f188c557120d16724829c2262521d80'),
#  ('Tokenix', '0x5eb1d37ae4ce0dcf2ac3f6f64c53ce7bedeb6a49'),
#  ('BTREE', '0x6bdde71cf0c751eb6d5edb8418e43d3d9427e436'),
#  ('(っ◔◡◔)っ ｱ乇W ', '0xeeeeecf99b5d7e9c0bca6e2769e895d8f956bbaf'),
#  ('HONO', '0x8f5ac7f3cfeffb6eb638a8add2d32661f82c03fd'),
#  ('Stubby Inu', '0x47011392cdfc9a16b78f18ab5718446fe7dc9bca'),
#  ('Broccoli', '0x7f3e4dbd84f5c8a5f15ef927557748cf2fbb77af'),
#  ('Protectron', '0x32a43da3e01e43355537ecbc3c0798e97e03c49e'),
#  ('StarShip', '0x1034cddd8222b26a556efca134bab73883258224'),
#  ('GANDALF', '0x021dd9191b697934941670d6e23f50a473fa0e0d'),
#  ('Y2B', '0xf9c12b27ce5058ab98ce11bd53900f84e18c0650'),
#  ('Butter', '0x0d248ce39e26fb00f911fb1e7a45a00d8c94341c'),
#  ('Banana', '0x718446feb676e0721900d4bffcd5f921b98947d9'),
#  ('UwU Lend', '0x55c08ca52497e2f1534b59e2917bf524d4765257'),
#  ('Foresight is Bliss', '0x6862e42f7e527a068ed98670fd637783bb022859'),
#  ('Apetama', '0x2918425e3b35d0a90748cf98a2d7aac128c8228f'),
#  ('Tholos', '0x207e14389183a94343942de7afbc607f57460618'),
#  ('HaHa', '0xd87d72248093597df8d56d2a53c1ab7c1a0cc8da'),
#  ('SATOSHIS VISION', '0x6c22910c6f75f828b305e57c6a54855d8adeabf8'),
#  ('TwitFi Token', '0xd4df22556e07148e591b4c7b4f555a17188cf5cf'),
#  ('Fluid', '0xb29edff8345b9d8039d8b9471c027d6e458a3c02'),
#  ('Dogelon', '0x761d38e5ddf6ccf6cf7c55759d5210750b5d60f3'),
#  ('Wojak Coin', '0x5026f006b85729a8b14553fae6af249ad16c9aab'),
#  ('SPHERE', '0xe1de6d0b11f98de92920a1d2b7c6ea30be2ba0c5'),
#  ('CryptoMoonPepe', '0x9af7a1dfb547dbe1c1baea132192bf85caf188b3'),
#  ('Feels Good Man', '0x1f19d846d99a0e75581913b64510fe0e18bbc31f'),
#  ('CAWKILLER', '0x88d81f4341ac842ab0637d2e9ecdddfef99e6813'),
#  ('Bull Coin', '0xf84210b3f764fe9f40475c118ca37d26ceacc80d'),
#  ('Cathedrafinance', '0xa6eedfdba0ecaeaf243ccabaa29a5ca3df77499d'),
#  ('VIRAL', '0x9d37f31a4e8c6af7f64f1ce6241d24f5cacd391c'),
#  ('Early', '0xa96a53aa616729821da80223bf48645f72eedd4d'),
#  ('mudskipper', '0x14559de4436ca01dbc3736f5bbda2d266982b3d3'),
#  ('Pandora Box', '0x256d0db20960c6831704786a4f50e90bd388275b'),
#  ('SHIBA INU', '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'),
#  ('Dai Stablecoin', '0x6b175474e89094c44da98b954eedeac495271d0f'),
#  ('Wrapped Rabbit', '0x822ba275d9acf8536a9f6d03707bc2e380410910'),
#  ('The Box', '0x066e941e168de3815cd6c8f63c46e8e3a2309ad7'),
#  ('PepeAI', '0xe509478a13fc0ca344cd9d9eea48f81511e08321'),
#  ('Satoshi Pepe', '0xedbb31b06380e25a0305dd85e9dc6c45af926549'),
#  ('Kirby Coin', '0x6c6b571f5af7aea536741e17f7502ae0b171abdf'),
#  ('Agility', '0x5f18ea482ad5cc6bc65803817c99f477043dce85'),
#  ('BONE SHIBASWAP', '0x9813037ee2218799597d83d4a5b6f3b6778218d9'),
#  ('n00dle', '0x2321537fd8ef4644bacdceec54e5f35bf44311fa'),
#  ('Mega', '0x282d0d15682acc34de0d4157cd07f35e5af325c7'),
#  ('Probably Nothing', '0x16afc6008ef155857eb13ecd8dd72c61c83cd744'),
#  ('MongCoin', '0x1ce270557c1f68cfb577b856766310bf8b47fd9c'),
#  ('Pepes Original Vision', '0xfcec9696d036065fd25d660c6c600445d6ba6b19'),
#  ('Trollface', '0x2e818c4d0fa3e7931ddd6c860ee1cab12ac22080'),
#  ('ROPSTEN ETH', '0x202130058ada9538071ec8d6630847d98d843b33'),
#  ('NotAnotherPepe', '0xdc9f4da3fa0a761296d90c37b6aa04881df03e31'),
#  ('BTRFLY', '0xc0d4ceb216b3ba9c3701b291766fdcba977cec3a'),
#  ('Clown World', '0x005e6de60b1b377c1de608f1df869617b4fa2199'),
#  ('WINDETH', '0xbb34f3e09c67319bcfa9bb84604b3f13b64a2658')]

# %% [markdown]
# Next we might want to ask a question like: what is the largest holding they both have? This is of course slightly underdetermined, so we need

# %%
print(len([k for k in intersect_dict.keys() if intersect_dict[k]==2]))
# Out:
# 256

# %%
print(len([k for k in intersect_dict.keys() if intersect_dict[k]==1]))
# Out:
# 8069

# %%
len(portfolios) #should be 2
# Out:
# 2
